# %% [markdown]
# <a href="https://colab.research.google.com/github/hossainrehan72-stack/e_commerce/blob/master/AdvancedPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ATM System

# %%
balance = 0
transactions = []

while True:
    print("\nMenu:")
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. View Transactions")
    print("5. Exit")
    choice = input("Choose an option (1-5): ")

    if choice == '1':
        amount = float(input("Enter deposit amount: "))
        if amount > 0:
            balance += amount
            transactions.append(f"Deposited: Rupees{amount:.2f}")
            print(f"Rupees{amount:.2f} deposited successfully.")
        else:
            print("Invalid amount. Please enter a positive number.")
    elif choice == '2':
        amount = float(input("Enter withdrawal amount: "))
        if 0 < amount <= balance:
            balance -= amount
            transactions.append(f"Withdrew: Rupees{amount:.2f}")
            print(f"Rupees{amount:.2f} withdrawn successfully.")
        else:
            print("Invalid amount. Please enter a positive number not exceeding your balance.")
    elif choice == '3':
        print(f"Current balance: Rupees{balance:.2f}")
    elif choice == '4':
        if transactions:
            print("Transaction History:")
            for transaction in transactions:
                print(transaction)
        else:
            print("No transactions yet.")
    elif choice == '5':
        print("Exiting the system.")
        break
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. View Transactions
# 5. Exit

# %% [markdown]
# Event tracking System

# %%
register_student=set()
rejected_student=set()

def registered_student(name):
    if name in rejected_student:
        print(f"{name} is already rejected")
    else:
        register_student.add(name)
        print(f"{name} is registered succesfully")

def reject_student(name):
    if name in register_student:
        register_student.remove(name)
    rejected_student.add(name)
    print(f"{name} is rejected succesfully")

def show():
    print("register students are :",register_student)
    print("rejected students are :",rejected_student)
    print("Total register students are :",len(register_student))
    print("Total rejected students are :",len(rejected_student))

while(True):
    print("options:")
    print("\n1. register students :")
    print("2. Reject Student")
    print("3. Show Status")
    print("4. Exit")

    c= input("enter the choice: ")
    if c=="1":
        name=input("enter the name of the student:")
        registered_student(name)
    elif c=="2":
        name=input("enter the name of the student")
        reject_student(name)
    elif c=="3":
        show()
    elif c=="4":
        break
    else:
        print("enter from the given options")
# Out:
# options:
#
# 1. register students :
# 2. Reject Student
# 3. Show Status
# 4. Exit
# enter the choice: 1
# enter the name of the student:Rehan
# Rehan is registered succesfully
# options:
#
# 1. register students :
# 2. Reject Student
# 3. Show Status
# 4. Exit
# enter the choice: 2
# enter the name of the studentSwadhin
# Swadhin is rejected succesfully
# options:
#
# 1. register students :
# 2. Reject Student
# 3. Show Status
# 4. Exit
# enter the choice: 3
# register students are : {'Rehan'}
# rejected students are : {'Swadhin'}
# Total register students are : 1
# Total rejected students are : 1
# options:
#
# 1. register students :
# 2. Reject Student
# 3. Show Status
# 4. Exit
# enter the choice: 4

# %% [markdown]
# ATM System using Multiple Accounts

# %%
def createAccount(d,cre,data):
  x=int(input("Enter the pin num : "))
  rx=int(input("Re-Enter the pin num : "))
  if(rx==x):
    d[cre.lower()]=x
    data[cre.lower()]=[0,[]]
    print("Bank Account Created Successfully")
  else:
    print("Wrong pin num Entered")
def authenticate(d,i):
  if i in d.keys():
    flag=False
    counter=0
    while True:
      x=int(input("Enter the Pin num : "))
      if(x==d[i]):
          flag=True
          print("Loading ...")
          break
      else:
          counter+=1
          print("Wrong PIN num")
          print("You have ",4-counter," more chances ")
      if(counter==4):
          print("Account locked for 24 hrs... try again after 24hrs otherwise contact your respective branch...")
          break
    return flag
  else:
    print("No such account")
    return False
def deposit(data,cre):
  amt = int(input("Enter Amount to be Deposit : "))
  data[cre][0]+=amt
  data[cre][1].append("Deposit : "+ str(amt))
  print("Amount Credited To Your Bank Account")
def withdraw(data,cre):
  amt = int(input("Enter Withdraw Amount :"))
  if(data[cre][0]<amt):
        print("Low balance\nPlease deposit first")
  else:
        data[cre][0]-=amt
        data[cre][1].append("Withdraw : "+str(amt))
        print("Amount withdrawn successfully")
def display(data,cre):
  print("Your current balance is : ",data[cre][0])
def printTransaction(data,crew):
  print("Transaction History")
  if(data[cre][1]==[]):
    print("No Transaction History")
  else:
    for i in data[cre][1]:
      print(i)
d={"rehan":8144,"omm":8984,"spydi":8260}
data={"rehan":[0,[]],"omm":[0,[]],"spydi":[0,[]]}
print("\t\tATM SYSTEM INITIATED")
cre=input("Enter the username of your account : ").lower()
o=authenticate(d,cre)
if o:
  while True:
      print("\n1.Deposit")
      print("\n2.Withdraw")
      print("\n3.Check Balance")
      print("\n4.Transaction History")
      print("\n5.Switch Account")
      print("\n6.Exit\n")
      choice = int(input("Enter your Choice :"))
      if(choice == 1):
          balance=deposit(data,cre)
      elif(choice==2):
          balance=withdraw(data,cre)
      elif(choice==3):
          display(data,cre)
      elif(choice==4):
          printTransaction(data,cre)
      elif(choice==5):
          org=cre
          cre=input("Enter the username : ").lower()
          if authenticate(d,cre):
            continue
          else:
            print("Wrong Information")
            cre=org
      elif(choice==6):
          print("Thanks for using the system")
          break
      else:
          print("Invalid Information Try Again")
else:
  flag=input("Enter whether you want to add the this -> ",cre,"account username or not ?? Y/N :").lower()
  if flag=='y':
    createAccount(d,cre,data)
  else:
    print("visit again")
# Out:
# 		ATM SYSTEM INITIATED
# Enter the username of your account : rehan
# Enter the Pin num : 8144
# Loading ...
#
# 1.Deposit
#
# 2.Withdraw
#
# 3.Check Balance
#
# 4.Transaction History
#
# 5.Switch Account
#
# 6.Exit
#
# Enter your Choice :5
# Enter the username : omm
# Enter the Pin num : 8144
# Wrong PIN num
# You have  3  more chances
# Enter the Pin num : 8260
# Wrong PIN num
# You have  2  more chances
# Enter the Pin num : 8144
# Wrong PIN num
# You have  1  more chances
# Enter the Pin num : 82600
# Wrong PIN num
# You have  0  more chances
# Account locked for 24 hrs... try again after 24hrs otherwise contact your respective branch...
# Wrong Information
#
# 1.Deposit
#
# 2.Withdraw
#
# 3.Check Balance
#
# 4.Transaction History
#
# 5.Switch Account
#
# 6.Exit
#
# Enter your Choice :6
# Thanks for using the system
